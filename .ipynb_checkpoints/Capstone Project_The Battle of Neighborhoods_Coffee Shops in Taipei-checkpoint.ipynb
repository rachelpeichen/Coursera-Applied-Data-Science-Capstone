# %% [markdown]
# ### Capstone - Battle of Neighborhoods

# %% [markdown]
# ### Exploring coffee shop business in Taipei ☕️
# Rachel Chen @Taipei Oct, 2020

# %% [markdown]
# ### 🔸 Introduction
# __This final project explores the competitive locations for coffee shops in Taipei, Taiwan.__ With the popularity of coffee culture in Taiwan, coffee shops proliferate rapidly in Taiwan in recent years, especially in the capital - Taipei. This project aims at potential entrepreneurs who want to start a new business of opening a new coffee shop.  Therefore, we will spot the clusters of items and thus we can discover which neighborhood has a high density of coffee shops business.  Also, We will find out the best location for starting up a new coffee shop business.
#
# _Reference:
# [Taipei-Wikipedia](https://en.wikipedia.org/wiki/Taipei), [How Social Media Fuels Taiwan's Growing Café Culture](https://international.thenewslens.com/article/105387)_

# %% [markdown]
# ### 🔸 Data
# For this project, we need to collect all coffee shops data in each neighborhood of Taipei.
#
# _Data source: [FourSquare API](https://developer.foursquare.com/)_
#
# Description : By using __Foursquare API__ via the "request" library, we will get all the venues in each neighborhood. We can filter these venues to get only "Coffee" related items. Therefore, we can get data from all coffee shops in Taipei City including their name, address, latitudes, longitudes, and ratings. We then can pick up the hot spot area where locates most of the venues. To assess the data, we use FourSquare API and folium for visualizing a particular area and predict an appropriate location for opening a new coffee shop in Taipei.

# %% [markdown]
# ### 🔸 Methodology
# • __FourSquare API__ will be used to locate all coffee shops in Taipei.
#
# • Data will be sorted based on ratings.
#
# • Finally, the data be will be visualized by using __folium__.

# %% [markdown]
# #### (1) We import all the libraries we need.

# %%
# Import library to deal with request
import requests 
# Import libraries for data analysis
import pandas as pd 
import numpy as np

# Install and import library for visualizing maps
# !pip install folium
import folium 
print('Import finished!')
# Out:
# Requirement already satisfied: folium in /Users/peipei/opt/anaconda3/lib/python3.8/site-packages (0.5.0)
# Requirement already satisfied: branca in /Users/peipei/opt/anaconda3/lib/python3.8/site-packages (from folium) (0.4.1)
# Requirement already satisfied: jinja2 in /Users/peipei/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.11.1)
# Requirement already satisfied: requests in /Users/peipei/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.22.0)
# Requirement already satisfied: six in /Users/peipei/opt/anaconda3/lib/python3.8/site-packages (from folium) (1.14.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/peipei/opt/anaconda3/lib/python3.8/site-packages (from jinja2->folium) (1.1.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/peipei/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/peipei/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/peipei/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/peipei/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (1.25.8)
# Import finished!

# %% [markdown]
# #### (2) Apply your credential ID on FourSquare.

# %%
CLIENT_ID = 'Your FourSquare ID' # Your FourSquare ID
CLIENT_SECRET = 'Your FourSquare Secret' # Your FourSquare Secret
VERSION = '20201028'
LIMIT = 100
print('Your credentails: ')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET: ' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: Your FourSquare ID
# CLIENT_SECRET: Your FourSquare Secret

# %% [markdown]
# Next, we can get requests near Taipei city.

# %%
# Get request near Taipei City

request_parameters = {
    "client_id": CLIENT_ID,
    "client_secret": CLIENT_SECRET,
    "v": '20201028',
    "section": "coffee",
    "near": "Taipei",
    "radius": 1000,
    "limit": 100}

data = requests.get("https://api.foursquare.com/v2/venues/explore", params = request_parameters)

# %%
data
# Out:
# <Response [200]>

# %% [markdown]
# #### (3) Transform data into json format and then we request geocode.

# %%
# Transform data into json format
d = data.json()["response"]
d.keys()
# Out:
# dict_keys(['suggestedFilters', 'geocode', 'headerLocation', 'headerFullLocation', 'headerLocationGranularity', 'query', 'totalResults', 'suggestedBounds', 'groups'])

# %%
print(d["headerLocationGranularity"], d["headerLocation"], d["headerFullLocation"])
print('\n')                                                         
print(d["suggestedBounds"], d["totalResults"])
print('\n') 
print(d["geocode"])
# Out:
# city Taipei Taipei
#
#
# {'ne': {'lat': 25.05519586803733, 'lng': 121.54266930512904}, 'sw': {'lat': 25.039539054156194, 'lng': 121.5209854171801}} 78
#
#
# {'what': '', 'where': 'taipei', 'center': {'lat': 25.04776, 'lng': 121.53185}, 'displayString': 'Taipei, Taiwan', 'cc': 'TW', 'geometry': {'bounds': {'ne': {'lat': 25.210402914205286, 'lng': 121.6659869734425}, 'sw': {'lat': 24.960319022116305, 'lng': 121.45875100000019}}}, 'slug': 'taipei', 'longId': '72057594039596277'}

# %% [markdown]
# #### (4) Then we start creating groups including recommended information.

# %%
d["groups"][0].keys()
# Out:
# dict_keys(['type', 'name', 'items'])

# %%
d["groups"][0]["type"], d["groups"][0]["name"]
# Out:
# ('Recommended Places', 'recommended')

# %% [markdown]
# #### (5) Creat feature items of coffee shops and their attributes such as id, address, name...

# %%
items = d["groups"][0]["items"]
print("Number of items: %i" % len(items))
items[0] # Test
# Out:
# Number of items: 78
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '54aaddea498e23ff9855c494',
#   'name': 'KiOSK',
#   'location': {'address': '新生北路一段40號',
#    'lat': 25.046284,
#    'lng': 121.531488,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 25.046284,
#      'lng': 121.531488}],
#    'postalCode': '104',
#    'cc': 'TW',
#    'city': '台北市',
#    'country': '臺灣',
#    'formattedAddress': ['新生北路一段40號', '台北市,  104', '臺灣']},
#   'categories': [{'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-5-54aaddea498e23ff9855c494-0'}

# %% [markdown]
# We can identify necessary factors from above dict for what we will use later to consider the probability of launching  location.

# %%
df_raw = []
for item in items:
    venue = item["venue"]
    categories, uid, name, location = venue["categories"], venue["id"], venue["name"], venue["location"]
    print(location)
    assert len(categories) == 1
    shortname = categories[0]["shortName"]
    address =  ''
    if hasattr(location, 'address'):
      address = location['address']
    if not "postalCode" in location:
        continue
    postalcode = location["postalCode"]
    lat = location["lat"]
    lng = location["lng"]
    datarow = (uid, name, shortname, address, postalcode, lat, lng)
    df_raw.append(datarow)
df = pd.DataFrame(df_raw, columns=["uid", "name", "shortname", "address", "postalcode", "lat", "lng"])
print("found %i coffee shops" % len(df))
df.head()
# Out:
# {'address': '新生北路一段40號', 'lat': 25.046284, 'lng': 121.531488, 'labeledLatLngs': [{'label': 'display', 'lat': 25.046284, 'lng': 121.531488}], 'postalCode': '104', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['新生北路一段40號', '台北市,  104', '臺灣']}
# {'address': '伊通街19巷8號', 'lat': 25.04881463348538, 'lng': 121.53499910429977, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04881463348538, 'lng': 121.53499910429977}], 'postalCode': '104', 'cc': 'TW', 'city': '中山區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['伊通街19巷8號', '中山區, 臺北市 104', '臺灣']}
# {'address': '新生北路一段15號', 'lat': 25.046633, 'lng': 121.531849, 'labeledLatLngs': [{'label': 'display', 'lat': 25.046633, 'lng': 121.531849}], 'cc': 'TW', 'neighborhood': '中山區', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['新生北路一段15號', '台北市', '臺灣']}
# {'address': '松江路93巷2號', 'lat': 25.050519528207236, 'lng': 121.53361336920035, 'labeledLatLngs': [{'label': 'display', 'lat': 25.050519528207236, 'lng': 121.53361336920035}], 'postalCode': '104', 'cc': 'TW', 'city': '中山區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['松江路93巷2號', '中山區, 臺北市 104', '臺灣']}
# {'address': '八德路一段1號', 'lat': 25.043829755234572, 'lng': 121.52887970057392, 'labeledLatLngs': [{'label': 'display', 'lat': 25.043829755234572, 'lng': 121.52887970057392}], 'postalCode': '100', 'cc': 'TW', 'neighborhood': 'Zhōngzhèng Qū', 'city': '中正區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['八德路一段1號', '中正區, 臺北市 100', '臺灣']}
# {'address': '忠孝東路二段64巷6號', 'lat': 25.042944247021197, 'lng': 121.52856767177582, 'labeledLatLngs': [{'label': 'display', 'lat': 25.042944247021197, 'lng': 121.52856767177582}], 'postalCode': '100', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['忠孝東路二段64巷6號', '台北市,  100', '臺灣']}
# {'address': '臨沂街27巷4-1號', 'lat': 25.041117377224893, 'lng': 121.53067826564411, 'labeledLatLngs': [{'label': 'display', 'lat': 25.041117377224893, 'lng': 121.53067826564411}], 'postalCode': '100', 'cc': 'TW', 'city': '中正區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['臨沂街27巷4-1號', '中正區, 臺北市 100', '臺灣']}
# {'address': '新生南路一段56巷16之4號', 'lat': 25.04099905231076, 'lng': 121.53190136814445, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04099905231076, 'lng': 121.53190136814445}], 'postalCode': '100', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['新生南路一段56巷16之4號', '台北市,  100', '臺灣']}
# {'address': '南京東路一段24號', 'lat': 25.051963, 'lng': 121.523724, 'labeledLatLngs': [{'label': 'display', 'lat': 25.051963, 'lng': 121.523724}], 'postalCode': '104', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['南京東路一段24號', '台北市,  104', '臺灣']}
# {'address': '市民大道三段2號', 'crossStreet': '金山北路', 'lat': 25.045213383443137, 'lng': 121.53104850297109, 'labeledLatLngs': [{'label': 'display', 'lat': 25.045213383443137, 'lng': 121.53104850297109}], 'postalCode': '10058', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['市民大道三段2號 (金山北路)', '台北市,  10058', '臺灣']}
# {'address': '伊通街33號1樓', 'crossStreet': '伊通公園旁', 'lat': 25.050507218703657, 'lng': 121.53510556441435, 'labeledLatLngs': [{'label': 'display', 'lat': 25.050507218703657, 'lng': 121.53510556441435}], 'postalCode': '104', 'cc': 'TW', 'city': '中山區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['伊通街33號1樓 (伊通公園旁)', '中山區, 臺北市 104', '臺灣']}
# {'address': '林森北路247號', 'lat': 25.053872844677684, 'lng': 121.52572968809423, 'labeledLatLngs': [{'label': 'display', 'lat': 25.053872844677684, 'lng': 121.52572968809423}], 'postalCode': '10447', 'cc': 'TW', 'neighborhood': 'Zhōngshān Qū, Taipei', 'city': '中山區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['林森北路247號', '中山區, 臺北市 10447', '臺灣']}
# {'address': '八德路一段28號', 'lat': 25.04363951596224, 'lng': 121.52989449964336, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04363951596224, 'lng': 121.52989449964336}], 'postalCode': '100', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['八德路一段28號', '台北市,  100', '臺灣']}
# {'lat': 25.04862767583337, 'lng': 121.5330111013143, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04862767583337, 'lng': 121.5330111013143}], 'postalCode': '104', 'cc': 'TW', 'city': '中山區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['中山區, 臺北市 104', '臺灣']}
# {'address': '忠孝東路二段134巷2號', 'lat': 25.0420208220301, 'lng': 121.5318050980568, 'labeledLatLngs': [{'label': 'display', 'lat': 25.0420208220301, 'lng': 121.5318050980568}], 'postalCode': '100', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['忠孝東路二段134巷2號', '台北市,  100', '臺灣']}
# {'address': '南京東路一段52號', 'lat': 25.052131010788756, 'lng': 121.52472850330139, 'labeledLatLngs': [{'label': 'display', 'lat': 25.052131010788756, 'lng': 121.52472850330139}], 'postalCode': '104', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['南京東路一段52號', '台北市,  104', '臺灣']}
# {'address': '中山北路一段33巷20弄6號', 'crossStreet': '市民大道', 'lat': 25.048275860482807, 'lng': 121.52197104845051, 'labeledLatLngs': [{'label': 'display', 'lat': 25.048275860482807, 'lng': 121.52197104845051}], 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['中山北路一段33巷20弄6號 (市民大道)', '台北市', '臺灣']}
# {'address': '忠孝東路三段217巷1弄6號', 'lat': 25.042318, 'lng': 121.539548, 'labeledLatLngs': [{'label': 'display', 'lat': 25.042318, 'lng': 121.539548}], 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['忠孝東路三段217巷1弄6號', '台北市', '臺灣']}
# {'address': '中山北路一段33巷20弄3號', 'crossStreet': '天津街', 'lat': 25.048135739108726, 'lng': 121.52215880084478, 'labeledLatLngs': [{'label': 'display', 'lat': 25.048135739108726, 'lng': 121.52215880084478}], 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['中山北路一段33巷20弄3號 (天津街)', '台北市', '臺灣']}
# {'address': '八德路一段1號', 'lat': 25.044253673413827, 'lng': 121.52925040048721, 'labeledLatLngs': [{'label': 'display', 'lat': 25.044253673413827, 'lng': 121.52925040048721}], 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['八德路一段1號', '台北市', '臺灣']}
# {'address': '忠孝東路一段31號', 'crossStreet': '紹興北街', 'lat': 25.044419442282862, 'lng': 121.52515626422525, 'labeledLatLngs': [{'label': 'display', 'lat': 25.044419442282862, 'lng': 121.52515626422525}], 'postalCode': '10049', 'cc': 'TW', 'city': '中正區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['忠孝東路一段31號 (紹興北街)', '中正區, 臺北市 10049', '臺灣']}
# {'address': '南京東路一段36號', 'lat': 25.05220203715147, 'lng': 121.52395766733518, 'labeledLatLngs': [{'label': 'display', 'lat': 25.05220203715147, 'lng': 121.52395766733518}], 'postalCode': '104', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['南京東路一段36號', '台北市,  104', '臺灣']}
# {'address': '建國北路一段67巷29號1樓', 'lat': 25.050974703180938, 'lng': 121.53833248273973, 'labeledLatLngs': [{'label': 'display', 'lat': 25.050974703180938, 'lng': 121.53833248273973}], 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['建國北路一段67巷29號1樓', '台北市', '臺灣']}
# {'address': '南京東路二段163號', 'lat': 25.05202168274771, 'lng': 121.53602162705958, 'labeledLatLngs': [{'label': 'display', 'lat': 25.05202168274771, 'lng': 121.53602162705958}], 'postalCode': '104', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['南京東路二段163號', '台北市,  104', '臺灣']}
# {'address': '臨沂街13巷7號', 'lat': 25.042305769054916, 'lng': 121.5310888465272, 'labeledLatLngs': [{'label': 'display', 'lat': 25.042305769054916, 'lng': 121.5310888465272}], 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['臨沂街13巷7號', '台北市', '臺灣']}
# {'address': '南京東路3段1號', 'lat': 25.05205711412559, 'lng': 121.53709740972394, 'labeledLatLngs': [{'label': 'display', 'lat': 25.05205711412559, 'lng': 121.53709740972394}], 'postalCode': '104', 'cc': 'TW', 'city': '中山區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['南京東路3段1號', '中山區, 臺北市 104', '臺灣']}
# {'address': '忠孝東路三段52號1樓', 'lat': 25.04190193176795, 'lng': 121.53532675831664, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04190193176795, 'lng': 121.53532675831664}], 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['忠孝東路三段52號1樓', '台北市', '臺灣']}
# {'address': '中山區伊通街66巷17號', 'lat': 25.052605092924782, 'lng': 121.53370049540652, 'labeledLatLngs': [{'label': 'display', 'lat': 25.052605092924782, 'lng': 121.53370049540652}], 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['中山區伊通街66巷17號', '台北市', '臺灣']}
# {'address': '天津街56-20號', 'lat': 25.050838561565126, 'lng': 121.52310804274356, 'labeledLatLngs': [{'label': 'display', 'lat': 25.050838561565126, 'lng': 121.52310804274356}], 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['天津街56-20號', '台北市', '臺灣']}
# {'address': '忠孝東路二段27號', 'lat': 25.043825, 'lng': 121.527843, 'labeledLatLngs': [{'label': 'display', 'lat': 25.043825, 'lng': 121.527843}], 'postalCode': '10058', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['忠孝東路二段27號', '台北市,  10058', '臺灣']}
# {'address': '八德路一段1號', 'lat': 25.04381901282198, 'lng': 121.52975933479959, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04381901282198, 'lng': 121.52975933479959}], 'postalCode': '100', 'cc': 'TW', 'city': '松山區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['八德路一段1號', '松山區, 臺北市 100', '臺灣']}
# {'address': '忠孝東路二段134巷3號', 'lat': 25.04166290508583, 'lng': 121.53174764517111, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04166290508583, 'lng': 121.53174764517111}], 'postalCode': '100', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['忠孝東路二段134巷3號', '台北市,  100', '臺灣']}
# {'address': '台北市伊通街127-3號', 'lat': 25.050826131654077, 'lng': 121.52311570626252, 'labeledLatLngs': [{'label': 'display', 'lat': 25.050826131654077, 'lng': 121.52311570626252}], 'postalCode': '104', 'cc': 'TW', 'city': 'Zhōngshān Qū', 'country': '臺灣', 'formattedAddress': ['台北市伊通街127-3號', 'Zhongshan Qu,  104', '臺灣']}
# {'address': '八德路一段1號', 'lat': 25.045127769794664, 'lng': 121.52896886452211, 'labeledLatLngs': [{'label': 'display', 'lat': 25.045127769794664, 'lng': 121.52896886452211}], 'postalCode': '100', 'cc': 'TW', 'neighborhood': 'Zhōngzhèng Qū', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['八德路一段1號', '台北市,  100', '臺灣']}
# {'address': '鎮江街3-1號', 'lat': 25.044623379963134, 'lng': 121.52519256517088, 'labeledLatLngs': [{'label': 'display', 'lat': 25.044623379963134, 'lng': 121.52519256517088}], 'postalCode': '100', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['鎮江街3-1號', '台北市,  100', '臺灣']}
# {'address': '八德路一段1號', 'crossStreet': '紅磚六合院W3棟', 'lat': 25.045251116658683, 'lng': 121.52769667531325, 'labeledLatLngs': [{'label': 'display', 'lat': 25.045251116658683, 'lng': 121.52769667531325}], 'postalCode': '100', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['八德路一段1號 (紅磚六合院W3棟)', '台北市,  100', '臺灣']}
# {'address': '南京東路二段218號', 'crossStreet': '建國北路口', 'lat': 25.05210750311172, 'lng': 121.53651604820577, 'labeledLatLngs': [{'label': 'display', 'lat': 25.05210750311172, 'lng': 121.53651604820577}], 'postalCode': '104', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['南京東路二段218號 (建國北路口)', '台北市,  104', '臺灣']}
# {'address': '松江路90巷3之2號', 'lat': 25.050484137982508, 'lng': 121.53217022097667, 'labeledLatLngs': [{'label': 'display', 'lat': 25.050484137982508, 'lng': 121.53217022097667}], 'postalCode': '104', 'cc': 'TW', 'city': 'Zhōngshān Qū', 'country': '臺灣', 'formattedAddress': ['松江路90巷3之2號', 'Zhongshan Qu,  104', '臺灣']}
# {'address': '八德路一段1號', 'lat': 25.044097302316946, 'lng': 121.52915399283187, 'labeledLatLngs': [{'label': 'display', 'lat': 25.044097302316946, 'lng': 121.52915399283187}], 'postalCode': '100', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['八德路一段1號', '台北市,  100', '臺灣']}
# {'address': '松江路65號', 'lat': 25.04954159259796, 'lng': 121.532946, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04954159259796, 'lng': 121.532946}], 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['松江路65號', '台北市', '臺灣']}
# {'address': '北平東路7號', 'lat': 25.047074, 'lng': 121.522298, 'labeledLatLngs': [{'label': 'display', 'lat': 25.047074, 'lng': 121.522298}], 'cc': 'TW', 'city': '中正區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['北平東路7號', '中正區, 臺北市', '臺灣']}
# {'address': '紹興南街4號', 'crossStreet': '忠孝東路', 'lat': 25.04376048511294, 'lng': 121.5249236148963, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04376048511294, 'lng': 121.5249236148963}], 'postalCode': '100', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['紹興南街4號 (忠孝東路)', '台北市,  100', '臺灣']}
# {'address': '南京東路二段1號', 'lat': 25.052468688072732, 'lng': 121.52777374863946, 'labeledLatLngs': [{'label': 'display', 'lat': 25.052468688072732, 'lng': 121.52777374863946}], 'postalCode': '104', 'cc': 'TW', 'city': '中山區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['南京東路二段1號', '中山區, 臺北市 104', '臺灣']}
# {'lat': 25.04443493021098, 'lng': 121.53114328837131, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04443493021098, 'lng': 121.53114328837131}], 'postalCode': '100', 'cc': 'TW', 'city': 'Zhōngzhèng Qū', 'country': '臺灣', 'formattedAddress': ['中正区,  100', '臺灣']}
# {'address': '八德路一段1號', 'lat': 25.04485027853593, 'lng': 121.52893532689946, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04485027853593, 'lng': 121.52893532689946}], 'postalCode': '100', 'cc': 'TW', 'city': '中正區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['八德路一段1號', '中正區, 臺北市 100', '臺灣']}
# {'address': '市民大道三段136號', 'lat': 25.044921133930693, 'lng': 121.53507691445623, 'labeledLatLngs': [{'label': 'display', 'lat': 25.044921133930693, 'lng': 121.53507691445623}], 'postalCode': '106', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['市民大道三段136號', '台北市,  106', '臺灣']}
# {'address': '臨沂街一號', 'lat': 25.04343697777806, 'lng': 121.53067684809328, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04343697777806, 'lng': 121.53067684809328}], 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['臨沂街一號', '台北市', '臺灣']}
# {'address': 'Art Gallery', 'lat': 25.043896, 'lng': 121.529347, 'labeledLatLngs': [{'label': 'display', 'lat': 25.043896, 'lng': 121.529347}], 'cc': 'TW', 'country': '臺灣', 'formattedAddress': ['Art Gallery', '臺灣']}
# {'address': '南京東路二段63號', 'lat': 25.052072757691178, 'lng': 121.53029408617031, 'labeledLatLngs': [{'label': 'display', 'lat': 25.052072757691178, 'lng': 121.53029408617031}], 'postalCode': '104', 'cc': 'TW', 'city': '中山區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['南京東路二段63號', '中山區, 臺北市 104', '臺灣']}
# {'address': '忠孝東路二段93-1號', 'lat': 25.043199518195358, 'lng': 121.53078459042636, 'labeledLatLngs': [{'label': 'display', 'lat': 25.043199518195358, 'lng': 121.53078459042636}], 'postalCode': '100', 'cc': 'TW', 'city': '中正區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['忠孝東路二段93-1號', '中正區, 臺北市 100', '臺灣']}
# {'address': '臨沂街13巷5號', 'lat': 25.04232956064412, 'lng': 121.53100389812293, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04232956064412, 'lng': 121.53100389812293}], 'postalCode': '100', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['臨沂街13巷5號', '台北市,  100', '臺灣']}
# {'address': '南京東路二段206號', 'lat': 25.052051, 'lng': 121.535995, 'labeledLatLngs': [{'label': 'display', 'lat': 25.052051, 'lng': 121.535995}], 'postalCode': '104', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['南京東路二段206號', '台北市,  104', '臺灣']}
# {'address': '市民大道三段178號', 'lat': 25.044365, 'lng': 121.537213, 'labeledLatLngs': [{'label': 'display', 'lat': 25.044365, 'lng': 121.537213}], 'postalCode': '106', 'cc': 'TW', 'city': '大安區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['市民大道三段178號', '大安區, 臺北市 106', '臺灣']}
# {'address': '忠孝東路二段134巷1號', 'lat': 25.04171, 'lng': 121.531713, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04171, 'lng': 121.531713}], 'postalCode': '100', 'cc': 'TW', 'country': '臺灣', 'formattedAddress': ['忠孝東路二段134巷1號', '100', '臺灣']}
# {'address': '台北紹興北街', 'crossStreet': '北平東路', 'lat': 25.045650554583204, 'lng': 121.52550336205299, 'labeledLatLngs': [{'label': 'display', 'lat': 25.045650554583204, 'lng': 121.52550336205299}], 'cc': 'TW', 'city': 'Jhongjheng District', 'country': '臺灣', 'formattedAddress': ['台北紹興北街 (北平東路)', 'Jhongjheng District', '臺灣']}
# {'address': '杭州南路一段11巷4號', 'lat': 25.043222, 'lng': 121.527223, 'labeledLatLngs': [{'label': 'display', 'lat': 25.043222, 'lng': 121.527223}], 'postalCode': '100', 'cc': 'TW', 'city': '中正區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['杭州南路一段11巷4號', '中正區, 臺北市 100', '臺灣']}
# {'address': '臨沂街27巷9-4號', 'lat': 25.041289, 'lng': 121.531498, 'labeledLatLngs': [{'label': 'display', 'lat': 25.041289, 'lng': 121.531498}], 'postalCode': '100', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['臨沂街27巷9-4號', '台北市,  100', '臺灣']}
# {'address': '南京東路三段48巷6號', 'lat': 25.050794, 'lng': 121.538342, 'labeledLatLngs': [{'label': 'display', 'lat': 25.050794, 'lng': 121.538342}], 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['南京東路三段48巷6號', '台北市', '臺灣']}
# {'lat': 25.042465492753333, 'lng': 121.52637046973996, 'labeledLatLngs': [{'label': 'display', 'lat': 25.042465492753333, 'lng': 121.52637046973996}], 'postalCode': '100', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['台北市,  100', '臺灣']}
# {'address': '伊通街116號', 'lat': 25.054484194679095, 'lng': 121.53490434140406, 'labeledLatLngs': [{'label': 'display', 'lat': 25.054484194679095, 'lng': 121.53490434140406}], 'postalCode': '104', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['伊通街116號', '台北市,  104', '臺灣']}
# {'address': '新生南路一段90號', 'lat': 25.04040571004045, 'lng': 121.53284941125219, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04040571004045, 'lng': 121.53284941125219}], 'postalCode': '100', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['新生南路一段90號', '台北市,  100', '臺灣']}
# {'address': '濟南路二段64-2號', 'lat': 25.040250727514426, 'lng': 121.53233646195575, 'labeledLatLngs': [{'label': 'display', 'lat': 25.040250727514426, 'lng': 121.53233646195575}], 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['濟南路二段64-2號', '台北市', '臺灣']}
# {'address': '南京東路三段77號', 'lat': 25.05209999508548, 'lng': 121.53873701266608, 'labeledLatLngs': [{'label': 'display', 'lat': 25.05209999508548, 'lng': 121.53873701266608}], 'cc': 'TW', 'city': '中山區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['南京東路三段77號', '中山區, 臺北市', '臺灣']}
# {'address': '長安東路二段174之1號', 'lat': 25.048339502413445, 'lng': 121.54031240440125, 'labeledLatLngs': [{'label': 'display', 'lat': 25.048339502413445, 'lng': 121.54031240440125}], 'cc': 'TW', 'city': '中山區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['長安東路二段174之1號', '中山區, 臺北市', '臺灣']}
# {'address': '龍江路2-7號', 'lat': 25.047435760498047, 'lng': 121.54039001464844, 'labeledLatLngs': [{'label': 'display', 'lat': 25.047435760498047, 'lng': 121.54039001464844}], 'postalCode': '104', 'cc': 'TW', 'city': 'Zhōngshān Qū', 'country': '臺灣', 'formattedAddress': ['龍江路2-7號', 'Zhongshan Qu,  104', '臺灣']}
# {'address': '中山區南京東路三段141號1樓；No. 131 Nanjing East Road Section 3, Zhongshan District', 'crossStreet': '龍江路', 'lat': 25.0519447083565, 'lng': 121.54038727083893, 'labeledLatLngs': [{'label': 'display', 'lat': 25.0519447083565, 'lng': 121.54038727083893}], 'postalCode': '104', 'cc': 'TW', 'city': '臺北市；Taipei', 'country': '臺灣', 'formattedAddress': ['中山區南京東路三段141號1樓；No. 131 Nanjing East Road Section 3, Zhongshan District (龍江路)', '臺北市；Taipei,  104', '臺灣']}
# {'address': '南京東路三段89巷3弄3號', 'lat': 25.052522, 'lng': 121.53908, 'labeledLatLngs': [{'label': 'display', 'lat': 25.052522, 'lng': 121.53908}], 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['南京東路三段89巷3弄3號', '台北市', '臺灣']}
# {'address': '新生南路一段60號', 'lat': 25.04078298290226, 'lng': 121.53280064142432, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04078298290226, 'lng': 121.53280064142432}], 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['新生南路一段60號', '台北市', '臺灣']}
# {'address': '4 南京東路三段89巷5弄', 'lat': 25.052799, 'lng': 121.539229, 'labeledLatLngs': [{'label': 'display', 'lat': 25.052799, 'lng': 121.539229}], 'postalCode': '104', 'cc': 'TW', 'city': '中山區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['4 南京東路三段89巷5弄', '中山區, 臺北市 104', '臺灣']}
# {'address': '建國南路一段166號', 'lat': 25.040924897084842, 'lng': 121.53723399166984, 'labeledLatLngs': [{'label': 'display', 'lat': 25.040924897084842, 'lng': 121.53723399166984}], 'postalCode': '106', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['建國南路一段166號', '台北市,  106', '臺灣']}
# {'lat': 25.04965884167595, 'lng': 121.52270875785297, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04965884167595, 'lng': 121.52270875785297}], 'cc': 'TW', 'country': '臺灣', 'formattedAddress': ['臺灣']}
# {'address': '忠孝東路三段217巷4弄2號', 'lat': 25.042729559126556, 'lng': 121.5396847989853, 'labeledLatLngs': [{'label': 'display', 'lat': 25.042729559126556, 'lng': 121.5396847989853}], 'postalCode': '106', 'cc': 'TW', 'city': '台北市', 'country': '臺灣', 'formattedAddress': ['忠孝東路三段217巷4弄2號', '台北市,  106', '臺灣']}
# {'address': '林森北路247號5樓', 'lat': 25.054146458446414, 'lng': 121.52519396170447, 'labeledLatLngs': [{'label': 'display', 'lat': 25.054146458446414, 'lng': 121.52519396170447}], 'postalCode': '10447', 'cc': 'TW', 'city': '中山區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['林森北路247號5樓', '中山區, 臺北市 10447', '臺灣']}
# {'lat': 25.05175860411602, 'lng': 121.54052107451258, 'labeledLatLngs': [{'label': 'display', 'lat': 25.05175860411602, 'lng': 121.54052107451258}], 'cc': 'TW', 'country': '臺灣', 'formattedAddress': ['臺灣']}
# {'address': '忠孝東路三段174號', 'lat': 25.041488634468983, 'lng': 121.53880566358566, 'labeledLatLngs': [{'label': 'display', 'lat': 25.041488634468983, 'lng': 121.53880566358566}], 'cc': 'TW', 'city': 'Da-an District', 'country': '臺灣', 'formattedAddress': ['忠孝東路三段174號', 'Da-an District', '臺灣']}
# {'address': '104台湾國台北市中山區南京東路三段109巷9號', 'lat': 25.052858623127083, 'lng': 121.53994125746343, 'labeledLatLngs': [{'label': 'display', 'lat': 25.052858623127083, 'lng': 121.53994125746343}], 'postalCode': '104', 'cc': 'TW', 'city': '中山區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['104台湾國台北市中山區南京東路三段109巷9號', '中山區, 臺北市 104', '臺灣']}
# {'address': '八德路二段277號', 'lat': 25.047094713480988, 'lng': 121.54168367385863, 'labeledLatLngs': [{'label': 'display', 'lat': 25.047094713480988, 'lng': 121.54168367385863}], 'postalCode': '104', 'cc': 'TW', 'city': '中山區', 'state': '臺北市', 'country': '臺灣', 'formattedAddress': ['八德路二段277號', '中山區, 臺北市 104', '臺灣']}
# {'lat': 25.04384787026639, 'lng': 121.5407440802876, 'labeledLatLngs': [{'label': 'display', 'lat': 25.04384787026639, 'lng': 121.5407440802876}], 'cc': 'TW', 'country': '臺灣', 'formattedAddress': ['臺灣']}
# found 53 coffee shops
#                         uid               name    shortname address  \
# 0  54aaddea498e23ff9855c494              KiOSK         Café
# 1  53788c7d498e4403b48271b6               沐鴉咖啡  Coffee Shop
# 2  4ce7cc4db99754816373f844            93巷人文空間         Café
# 3  4dc6a209c65b89d3ca8be21a      三重奏 Trio Café     Cocktail
# 4  4b88a745f964a520f30632e3  CoffeeLab (咖啡實驗室)         Café
#
#   postalcode        lat         lng
# 0        104  25.046284  121.531488
# 1        104  25.048815  121.534999
# 2        104  25.050520  121.533613
# 3        100  25.043830  121.528880
# 4        100  25.042944  121.528568

# %% [markdown]
# #### (6) Finally, we can get the coordinate of Taipei and create a folium map to visualize data.
# Please be noted that the maps may not be shown completely in Github. Please go to "README" file for maps. 😉

# %%
Taipei_center = d["geocode"]["center"]
print('Coordinate of Taipei: ', Taipei_center)
# Out:
# Coordinate of Taipei:  {'lat': 25.04776, 'lng': 121.53185}

# %%
from folium import plugins

map_Taipei = folium.Map(location=[25.04776, 121.53185], zoom_start = 15)

def add_markers(df):
    for (j, row) in df.iterrows():
        label = folium.Popup(row["name"], parse_html = True)
        folium.CircleMarker(
            [row["lat"], row["lng"]],
            radius = 5,
            popup = label,
            color = '#ed5c5c',
            fill = True,
            fill_color = '#de9c6a',
            fill_opacity = 0.6,
            parse_html = False).add_to(map_Taipei)

add_markers(df)
hm_data = df[["lat", "lng"]].to_numpy().tolist()
map_Taipei.add_child(plugins.HeatMap(hm_data))

map_Taipei
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We can tell which neighborhood has a high density of coffee shops from above map.
#
# Next, we still need to identify the location for starting a new cofee shop. This location should meet below requirements:
#
# (1) Locate at the hot spot area that we show in previous map
#
# (2) Keep in a certain distance from existing coffee shops to avoid the competivity of business

# %%
lat = 25.04776
lng = 121.53185

map_Taipei = folium.Map(location=[lat, lng], zoom_start = 15)
add_markers(df)


folium.CircleMarker(
    [lat, lng],
    radius = 18,
    popup = 'New coffee shops location',
    color = '#f230e9',
    fill = True,
    fill_color = '#fff533',
    fill_opacity = 0.7,
    parse_html = False).add_to(map_Taipei)

map_Taipei
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Here we find out the best location for starting a new coffee shop (yellow spot in the map). 😃
